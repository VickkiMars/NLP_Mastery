# %% [markdown]
# <a href="https://colab.research.google.com/github/VickkiMars/NLP_Mastery/blob/main/classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.5)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.6.17)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.10)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/chaitanyarahalkar/positive-and-negative-sentences')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
# Your Kaggle username: victorthamartian
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/chaitanyarahalkar/positive-and-negative-sentences
# Downloading positive-and-negative-sentences.zip to ./positive-and-negative-sentences
# 100%|██████████| 484k/484k [00:00<00:00, 43.2MB/s]

# %%
import unicodedata
import string

# %%
all_letters = string.ascii_letters + " .,;'"

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

# %%
def load_data(filepath):
  # Open the file with the correct encoding (e.g., latin-1)
  with open(filepath+"positive.txt", encoding='latin-1') as f:
    positive = f.read()

  with open(filepath+"negative.txt", encoding='latin-1') as f:
    negative = f.read()
  positive, negative = positive.split('\n'), negative.split('\n')
  return positive, negative

# %%
def print_samples(no):
  positive, negative = load_data('positive-and-negative-sentences/')
  for i in range(no):
    print(f'Positive sample: {positive[i]}')
    print(f'Negative sample: {negative[i]}')
    print('\n')

# %%
positive, negative = load_data(r'positive-and-negative-sentences/')
print_samples(3)
# Out:
# Positive sample: the rock is destined to be the 21st century's new " conan " and that he's going to make a splash even greater than arnold schwarzenegger , jean claud van damme or steven segal .
# Negative sample: simplistic , silly and tedious .
#
#
# Positive sample: the gorgeously elaborate continuation of " the lord of the rings " trilogy is so huge that a column of words cannot adequately describe co writer/director peter jackson's expanded vision of j . r . r . tolkien's middle earth .
# Negative sample: it's so laddish and juvenile , only teenage boys could possibly find it funny .
#
#
# Positive sample: effective but too tepid biopic
# Negative sample: exploitative and largely devoid of the depth or sophistication that would make watching such a graphic treatment of the crimes bearable .

# %%
def max_length(positive, negative):
  max_length = 0
  for line in positive:
    max_length = max(max_length, len(line))
  for line in negative:
    max_length = max(max_length, len(line))
  return max_length

# %%
import pandas as pd

# %%
def create_dataset(filepath):
  positive, negative = load_data(filepath)

  # Create labels
  positive_labels = ['positive'] * len(positive)
  negative_labels = ['negative'] * len(negative)
  positive_labels = [0 if label == 'positive' else 1 for label in positive_labels]
  negative_labels = [0 if label == 'positive' else 1 for label in negative_labels]
  # Combine sentences and labels
  text = positive + negative
  labels = positive_labels + negative_labels

  # Create the dictionary
  data = {'text': text, 'label': labels}
  return data

# %%
data = pd.DataFrame(create_dataset('positive-and-negative-sentences/'))
print(data.isnull().sum(axis=1).eq(data.shape[1]).sum())
data = data.sample(frac=1).reset_index(drop=True)
data.to_csv('data.csv', index=False)
# Out:
# 0

# %%
import tensorflow as tf

# %%
BATCH_SIZE=16
dataset = tf.data.experimental.CsvDataset(
    "/content/data.csv",
    [tf.string, tf.int32],
    header=True,
)

# %%
for text, label in dataset.take(1493):
  print(text, label)
# Out:
# tf.Tensor(b'philosophically , intellectually and logistically a mess . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it grabs you in the dark and shakes you vigorously for its duration . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'more timely than its director could ever have dreamed , this quietly lyrical tale probes the ambiguous welcome extended by iran to the afghani refugees who streamed across its borders , desperate for work and food . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it's tough to tell which is in more abundant supply in this woefully hackneyed movie , directed by scott kalvert , about street gangs and turf wars in 1958 brooklyn -- stale cliches , gratuitous violence , or empty machismo . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"both lead performances are oscar size . quaid is utterly fearless as the tortured husband living a painful lie , and moore wonderfully underplays the long suffering heroine with an unflappable '50s dignity somewhere between jane wyman and june cleaver . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"kinnear doesn't aim for our sympathy , but rather delivers a performance of striking skill and depth . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a generation x artifact , capturing a brief era of insanity in the sports arena that surely cannot last . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"evelyn's strong cast and surehanded direction make for a winning , heartwarming yarn . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"while most films these days are about nothing , this film seems to be about everything that's plaguing the human spirit in a relentlessly globalizing world . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a chilling tale of one of the great crimes of 20th century france : the murder of two rich women by their servants in 1933 . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it's impossible to even categorize this as a smutty guilty pleasure . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'as exciting as all this exoticism might sound to the typical pax viewer , the rest of us will be lulled into a coma . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"a minor work yet there's no denying the potency of miller's strange , fleeting brew of hopeful perseverance and hopeless closure . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it comes off as so silly that you wouldn't be surprised if ba , murdock and rest of the a-team were seen giving chase in a black and red van . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the master of disguise represents adam sandler's latest attempt to dumb down the universe . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'becomes a fascinating study of isolation and frustration that successfully recreates both the physical setting and emotional tensions of the papin sisters . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"i'm not sure which will take longer to heal : the welt on johnny knoxville's stomach from a riot-control projectile or my own tortured psyche . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'one of the best silly horror movies of recent memory , with some real shocks in store for unwary viewers . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'will be far more interesting to the soderbergh faithful than it will be to the casual moviegoer who might be lured in by julia roberts . . . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"i can't recommend it . but it's surprisingly harmless . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"at least it's a fairly impressive debut from the director , charles stone iii . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'charming and funny ( but ultimately silly ) movie . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a delightful , if minor , pastry of a movie . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a resonant tale of racism , revenge and retribution . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'while puerile men dominate the story , the women shine . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"a vile , incoherent mess . . . a scummy ripoff of david cronenberg's brilliant 'videodrome . '", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'this is a movie so insecure about its capacity to excite that it churns up not one but two flagrantly fake thunderstorms to underscore the action . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the ethos of the chelsea hotel may shape hawke's artistic aspirations , but he hasn't yet coordinated his own dv poetry with the beat he hears in his soul . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'hu and liu offer natural , matter of fact performances that glint with sorrow , longing and love . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a silly , self-indulgent film about a silly , self-indulgent filmmaker . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's neither as romantic nor as thrilling as it should be . but it offers plenty to ponder and chew on as its unusual relationship slowly unfolds . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the plot of the comeback curlers isn't very interesting actually , but what i like about men with brooms and what is kind of special is how the film knows what's unique and quirky about canadians . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'what a great way to spend 4 units of your day . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a live-action cartoon , a fast-moving and cheerfully simplistic 88 minutes of exaggerated action put together with the preteen boy in mind . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a provocative movie about loss , anger , greed , jealousy , sickness and love . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"just because it really happened to you , honey , doesn't mean that it's interesting to anyone else . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the characters are based on stock clich\xc3\xa9s , and the attempt to complicate the story only defies credibility . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'get out your pooper-scoopers . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'like so many other allegedly scary movies , it gets so tangled up in the twist that it chokes the energy right out of the very audience it seeks to frighten . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it is most remarkable not because of its epic scope , but because of the startling intimacy it achieves despite that breadth . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'one of those energetic surprises , an original that pleases almost everyone who sees it . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the old world  meets new mesh is incarnated in the movie's soundtrack , a joyful effusion of disco bollywood that , by the end of monsoon wedding , sent my spirit soaring out of the theater . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a few artsy flourishes aside , narc is as gritty as a movie gets these days . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'in a summer of clones , harvard man is something rare and riveting : a wild ride that relies on more than special effects . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"nearly surreal , dabbling in french , this is no simple movie , and you'll be taking a risk if you choose to see it . i enjoyed the ride ( bumps and all ) , creamy depth , and ultimate theme . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'it is life affirming and heartbreaking , sweet without the decay factor , funny and sad . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'julia is played with exasperating blandness by laura regan . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'weaves a spell over you , with its disturbingly close-up look at damaged psyches and its subtle undercurrents of danger . but its awkward structure keeps breaking the spell . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a compelling pre wwii drama with vivid characters and a warm , moving message . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'sorority boys , which is as bad at it is cruel , takes every potential laugh and stiletto-stomps the life out of it . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a comedy drama of nearly epic proportions rooted in a sincere performance by the title character undergoing midlife crisis . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'control-alt-delete simone as quickly as possible', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the movie resolutely avoids all the comic possibilities of its situation , and becomes one more dumb high school comedy about sex gags and prom dates . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'for all of its insights into the dream world of teen life , and its electronic expression through cyber culture , the film gives no quarter to anyone seeking to pull a cohesive story out of its 2 1/2-hour running time . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"this low-rent -- and even lower-wit -- rip-off of the farrelly brothers' oeuvre gets way too mushy -- and in a relatively short amount of time . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"ozpetek's effort has the scope and shape of an especially well executed television movie . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'confirms the nagging suspicion that ethan hawke would be even worse behind the camera than he is in front of it . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the story is familiar from its many predecessors ; like them , it eventually culminates in the not-exactly -stunning insight that crime doesn't pay . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a mostly believable , refreshingly low key and quietly inspirational little sports drama . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"romanek keeps the film constantly taut . . . reflecting the character's instability with a metaphorical visual style and an unnerving , heartbeat like score . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'neatly constructed thriller . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"[carvey's] characters are both overplayed and exaggerated , but then again , subtlety has never been his trademark . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"kinnear's performance is a career defining revelation . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'acting , particularly by tambor , almost makes " never again " worthwhile , but [writer/director] schaeffer should follow his titular advice', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a fascinating but choppy documentary . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'quick : who wants to see a comedy about shoddy airport security ? ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'are monsters born , or made ? ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'vile and tacky are the two best adjectives to describe ghost ship . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'not just unlikable . disturbing . disgusting . without any redeeming value whatsoever . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's like every bad idea that's ever gone into an after-school special compiled in one place , minus those daytime programs' slickness and sophistication ( and who knew they even had any ? ) . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'catch it . . . if you can ! ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'complex , affecting and uniquely almodovar , the film evokes strong emotions and pushes viewers to question their deepest notions of moral right and wrong . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'although made on a shoestring and unevenly acted , conjures a lynch like vision of the rotting underbelly of middle america . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'it is intensely personal and yet    unlike quills    deftly shows us the temper of the times . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'though its rather routine script is loaded with familiar situations , the movie has a cinematic fluidity and sense of intelligence that makes it work more than it probably should . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a well made thriller with a certain level of intelligence and non reactionary morality . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a full experience , a love story and a murder mystery that expands into a meditation on the deep deceptions of innocence . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'lends itself to the narcotizing bland ( sinister , though not nearly so sinister as the biennial disney girl movie ) machinations of the biennial disney boy movie . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'even those of a single digit age will be able to recognize that this story is too goofy . . . even for disney . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the movie barely makes sense , with its unbelievable na\xc3\xafvet\xc3\xa9 and arbitrary flashbacks . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'rarely does such high profile talent serve such literate material . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'adults will wish the movie were less simplistic , obvious , clumsily plotted and shallowly characterized . but what are adults doing in the theater at all ? ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"though writer/director bart freundlich's film ultimately becomes a simplistic story about a dysfunctional parent child relationship , it has some special qualities and the soulful gravity of crudup's anchoring performance . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"breen's script is sketchy with actorish notations on the margin of acting . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'in its ragged , cheap and unassuming way , the movie works . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"any film that doesn't even in passing mention political prisoners , poverty and the boat loads of people who try to escape the country is less a documentary and more propaganda by way of a valentine sealed with a kiss . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'after collateral damage , you might imagine that most every aggrieved father clich\xc3\xa9 has been unturned . but no . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"when a film is created solely because it's a marketable product , soulless and ugly movies like this are the result . let your silly childhood nostalgia slumber unmolested . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the transporter is as lively and as fun as it is unapologetically dumb', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the importance of being earnest , so thick with wit it plays like a reading from bartlett's familiar quotations", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'qualities that were once amusing are becoming irritating . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"i like all four of the lead actors a lot and they manage to squeeze a few laughs out of the material , but they're treading water at best in this forgettable effort . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'stripped almost entirely of such tools as nudity , profanity and violence , labute does manage to make a few points about modern man and his problematic quest for human connection . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"an ambitious 'what if ? ' that works . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'since the movie is based on a nicholas sparks best seller , you know death is lurking around the corner , just waiting to spoil things . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'scarcely worth a mention apart from reporting on the number of tumbleweeds blowing through the empty theatres graced with its company . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b' " collateral damage " goes by the numbers and reps decent action entertainment \xc2\x96 until the silly showdown ending that forces the viewer to totally suspend disbelief', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the big-screen scooby makes the silly original cartoon seem smart and well-crafted in comparison . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"like the chelsea's denizens . . . burdette's collage-form scenario tends to over-romanticize the spiritual desolation of the struggling artiste . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"legendary irish writer brendan behan's memoir , borstal boy , has been given a loving screen transferral . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it's stylishly directed with verve . . . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'if this silly little cartoon can inspire a few kids not to grow up to be greedy bastards , more power to it . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'this is what imax was made for : strap on a pair of 3 d goggles , shut out the real world , and take a vicarious voyage to the last frontier    space . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a movie that , rather than skip along the seine , more or less slogs its way through soggy paris , tongue uncomfortably in cheek . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'high drama , disney-style - a wing and a prayer and a hunky has-been pursuing his castle in the sky . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'comes off more like a misdemeanor , a flat , unconvincing drama that never catches fire . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the action is reasonably well-done . . . yet story , character and comedy bits are too ragged to ever fit smoothly together . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"i encourage young and old alike to go see this unique and entertaining twist on the classic whale's tale    you won't be sorry ! ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"haneke keeps us at arm's length . guided more by intellect than heart , his story flattens instead of sharpens . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'unfortunately , neither sendak nor the directors are particularly engaging or articulate . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"lookin' for sin , american style ? try hell house , which documents the cautionary christian spook a rama of the same name . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'it recycles every clich\xc3\xa9 about gays in what is essentially an extended soap opera . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"even legends like alfred hitchcock and john huston occasionally directed trifles . . . so it's no surprise to see a world-class filmmaker like zhang yimou behind the camera for a yarn that's ultimately rather inconsequential . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'when in doubt , the film ratchets up the stirring soundtrack , throws in a fish-out-of-water gag and lets the cliched dialogue rip . or else a doggie winks . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"cinematic pyrotechnics aside , the only thing avary seems to care about are mean giggles and pulchritude . it makes sense that he went back to school to check out the girls -- his film is a frat boy's idea of a good time . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'what might have been readily dismissed as the tiresome rant of an aging filmmaker still thumbing his nose at convention takes a surprising , subtle turn at the midway point . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'another rent installment for the ian fleming estate . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"ben affleck as jack ryan , tom clancy's intrepid hero ? ridiculous . what's next ? d . j . qualls as indiana jones ? or tom green as han solo ? ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'as the latest bid in the tv-to-movie franchise game , i spy makes its big-screen entry with little of the nervy originality of its groundbreaking small-screen progenitor . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'complex , sinuously plotted and , somehow , off-puttingly cold . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'mixes likeable personalities , inventive photography and cutting , and wall to wall toe tapping music to paint a picture of a subculture that is at once exhilarating , silly , perverse , hopeful and always fun . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'stirs potentially enticing ingredients into an uneasy blend of ghost and close encounters of the third kind . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'for all its problems . . . the lady and the duke surprisingly manages never to grow boring . . . which proves that rohmer still has a sense of his audience . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'this is a throwaway , junk-food movie whose rap soundtrack was better tended to than the film itself . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the power of shanghai ghetto , a documentary by dana janklowicz mann and amir mann , rests in the voices of men and women , now in their 70s , who lived there in the 1940s . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'i felt sad for lise not so much because of what happens as because she was captured by this movie when she obviously belongs in something lighter and sunnier , by rohmer , for example . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"this movie has a strong message about never giving up on a loved one , but it's not an easy movie to watch and will probably disturb many who see it . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a good-looking but ultimately pointless political thriller with plenty of action and almost no substance . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a sub-formulaic slap in the face to seasonal cheer . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'plays less like a coming-of-age romance than an infomercial . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'not a film to rival to live , but a fine little amuse bouche to keep your appetite whetted . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"ultimately , sarah's dedication to finding her husband seems more psychotic than romantic , and nothing in the movie makes a convincing case that one woman's broken heart outweighs all the loss we witness . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'elegantly produced and expressively performed , the six musical numbers crystallize key plot moments into minutely detailed wonders of dreamlike ecstasy . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"a grand fart coming from a director beginning to resemble someone's crazy french grandfather . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"a surprisingly charming and even witty match for the best of hollywood's comic book adaptations . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'if the tuxedo actually were a suit , it would fit chan like a $99 bargain-basement special . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's supposed to be a humorous , all-too-human look at how hope can breed a certain kind of madness -- and strength -- but it never quite adds up . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"while the story does seem pretty unbelievable at times , it's awfully entertaining to watch . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b' . . . certainly an entertaining ride , despite many talky , slow scenes . but something seems to be missing . a sense of real magic , perhaps . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it's fun , but the code talk will fly right over everyone's head", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'has far more energy , wit and warmth than should be expected from any movie with a " 2 " at the end of its title . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a cautionary tale about the grandiosity of a college student who sees himself as impervious to a fall . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'delightfully rendered', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'vampire epic succeeds as spooky action packed trash of the highest order . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"parker cannot sustain the buoyant energy level of the film's city beginnings into its country conclusion", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'despite the holes in the story and the somewhat predictable plot , moments of the movie caused me to jump in my chair . . . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the skills of a calculus major at m . i . t . are required to balance all the formulaic equations in the long-winded heist comedy who is cletis tout ? ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"intriguing documentary which is emotionally diluted by focusing on the story's least interesting subject . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"eddie murphy and owen wilson have a cute partnership in i spy , but the movie around them is so often nearly nothing that their charm doesn't do a load of good . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the whole thing's fairly lame , making it par for the course for disney sequels . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it dares to be a little different , and that shading is what makes it worthwhile . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'kinnear gives a tremendous performance . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"a living testament to the power of the eccentric and the strange . the fact that it isn't very good is almost beside the point . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"de niro and mcdormand give solid performances , but their screen time is sabotaged by the story's inability to create interest . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the actors don't inhabit their roles -- they're trapped by them , forced to change behavior in bizarre unjustified fashion and spout dialog that consists mostly of platitudes . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's refreshing to see a romance this smart . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a chiller resolutely without chills . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'claims to sort the bad guys from the good , which is its essential problem . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'deliriously funny , fast and loose , accessible to the uninitiated , and full of surprises', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a first class , thoroughly involving b movie that effectively combines two surefire , beloved genres    the prison flick and the fight film . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a party hearty teen flick that scalds like acid . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'clooney directs this film always keeping the balance between the fantastic and the believable . . . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'if you can swallow its absurdities and crudities lagaan really is enormously good fun . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'passionate , irrational , long suffering but cruel as a tarantula , helga figures prominently in this movie , and helps keep the proceedings as funny for grown ups as for rugrats . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the film hinges on its performances , and both leads are up to the task . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'most fish stories are a little peculiar , but this is one that should be thrown back in the river . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a major waste . . . generic . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'this film seems thirsty for reflection , itself taking on adolescent qualities . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"there is no denying the power of polanski's film . . . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'very stupid and annoying . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'movies like high crimes flog the dead horse of surprise as if it were an obligation . how about surprising us by trying something new ? ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"written , flatly , by david kendall and directed , barely , by there's something about mary co-writer ed decter . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"sandra bullock , despite downplaying her good looks , carries a little too much ain't- she-cute baggage into her lead role as a troubled and determined homicide cop to quite pull off the heavy stuff . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'for the most part stevens glides through on some solid performances and witty dialogue . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'it never quite makes it to the boiling point , but manages to sustain a good simmer for most of its running time . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'has the rare capability to soothe and break your heart with a single stroke . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the laser projected paintings provide a spell casting beauty , while russell and dreyfus are a romantic pairing of hearts , preciously exposed as history corners them . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'has the capability of effecting change and inspiring hope . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the talk-heavy film plays like one of robert altman's lesser works . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'wonder , hope and magic can never escape the heart of the boy when the right movie comes along , especially if it begins with the name of star wars', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"i'm not a fan of the phrase 'life affirming' because it usually means 'schmaltzy , ' but real women have curves truly is life affirming . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'dogtown & z boys evokes the blithe rebel fantasy with the kind of insouciance embedded in the sexy demise of james dean . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b" . . . an otherwise intense , twist and turn thriller that certainly shouldn't hurt talented young gaghan's resume . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"sitting in the third row of the imax cinema at sydney's darling harbour , but i sometimes felt as though i was in the tiny two seater plane that carried the giant camera around australia , sweeping and gliding , banking and hovering over some of the most not", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'together , miller , kuras and the actresses make personal velocity into an intricate , intimate and intelligent journey . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'el crimen del padre amaro would likely be most effective if used as a tool to rally anti-catholic protestors . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"at a time when commercialism has squeezed the life out of whatever idealism american moviemaking ever had , godfrey reggio's career shines like a lonely beacon . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the trouble is , its filmmakers run out of clever ideas and visual gags about halfway through . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'mais um momento inspirado de david fincher . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a very good film sits in the place where a masterpiece should be . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'it sticks rigidly to the paradigm , rarely permitting its characters more than two obvious dimensions and repeatedly placing them in contrived , well-worn situations . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'edited and shot with a syncopated style mimicking the work of his subjects , pray turns the idea of the documentary on its head , making it rousing , invigorating fun lacking any mtv puffery . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the pianist is the film roman polanski may have been born to make . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"flamboyant in some movies and artfully restrained in others , 65 year old jack nicholson could be looking at his 12th oscar nomination by proving that he's now , more than ever , choosing his roles with the precision of the insurance actuary . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the film is hampered by its predictable plot and paper-thin supporting characters . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the fluid motion is astounding on any number of levels    including the physical demands made on b\xc3\xbcttner    and it implies in its wake the intractable , irreversible flow of history . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the film presents visceral and dangerously honest revelations about the men and machines behind the curtains of our planet . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'if villainous vampires are your cup of blood , blade 2 is definitely a cut above the rest . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'what the film lacks in general focus it makes up for in compassion , as corcuera manages to find the seeds of hope in the form of collective action . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a story about intelligent high school students that deals with first love sweetly but also seriously . it is also beautifully acted . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"to those who have not read the book , the film is a much better mother daughter tale than last summer's 'divine secrets of the ya ya sisterhood , ' but that's not saying much . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the one not-so-small problem with expecting is that the entire exercise has no real point . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'what with all the blanket statements and dime-store ruminations on vanity , the worries of the rich and sudden wisdom , the film becomes a sermon for most of its running time . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'just too silly and sophomoric to ensnare its target audience . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'waydowntown is by no means a perfect film , but its boasts a huge charm factor and smacks of originality . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'those who would follow haneke on his creepy explorations . . . are rewarded by brutal , committed performances from huppert and magimel . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"although olivier assayas' elegantly appointed period drama seems , at times , padded with incident in the way of a too conscientious adaptation . . . its three hour running time plays closer to two . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'an entertaining , if ultimately minor , thriller . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"first , for a movie that tries to be smart , it's kinda dumb . and second , what's with all the shooting ? ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'nothing about it fits . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'though impostor deviously adopts the guise of a modern motion picture , it too is a bomb . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'rarely , a movie is more than a movie . go . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the most surprising thing about this film is that they are actually releasing it into theaters . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'certain to be distasteful to children and adults alike , eight crazy nights is a total misfire . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the beauty of alexander payne's ode to the everyman is in the details . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"i won't argue with anyone who calls 'slackers' dumb , insulting , or childish . . . but i laughed so much that i didn't mind . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it doesn't offer audiences any way of gripping what its point is , or even its attitude toward its subject . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"talkiness isn't necessarily bad , but the dialogue frequently misses the mark . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'nothing but one relentlessly depressing situation after another for its entire running time , something that you could easily be dealing with right now in your lives . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a processed comedy chop suey . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'young everlyn sampi , as the courageous molly craig , simply radiates star power potential in this remarkable and memorable film . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'solaris " is a shapeless inconsequential move relying on the viewer to do most of the work . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'drops you into a dizzying , volatile , pressure cooker of a situation that quickly snowballs out of control , while focusing on the what much more than the why . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"peralta's mythmaking could have used some informed , adult hindsight . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'both a detective story and a romance spiced with the intrigue of academic skullduggery and politics . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'at heart the movie is a deftly wrought suspense yarn whose richer shadings work as coloring rather than substance . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'successfully blended satire , high camp and yet another sexual taboo into a really funny movie . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'while the isle is both preposterous and thoroughly misogynistic , its vistas are incredibly beautiful to look at . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'while centered on the life experiences of a particular theatrical family , this marvelous documentary touches    ever so gracefully    on the entire history of the yiddish theater , both in america and israel . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'in the era of the sopranos , it feels painfully redundant and inauthentic . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"why , you may ask , why should you buy the movie milk when the tv cow is free ? there's no good answer to that one . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"while there's something intrinsically funny about sir anthony hopkins saying 'get in the car , bitch , ' this jerry bruckheimer production has little else to offer", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'terrible . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'an ingenious and often harrowing look at damaged people and how families can offer either despair or consolation . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"carrying this wafer-thin movie on his nimble shoulders , chan wades through putrid writing , direction and timing with a smile that says , 'if i stay positive , maybe i can channel one of my greatest pictures , drunken master . '", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the real star of this movie is the score , as in the songs translate well to film , and it's really well directed . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"although there are several truly jolting scares , there's also an abundance of hackneyed dialogue and more silly satanic business than you can shake a severed limb at . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'what a bewilderingly brilliant and entertaining movie this is . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the difference between cho and most comics is that her confidence in her material is merited . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"at a time when we've learned the hard way just how complex international terrorism is , collateral damage paints an absurdly simplistic picture . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"this is the first full scale wwii flick from hong kong's john woo . he's not good with people . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"mandel holland's direction is uninspired , and his scripting unsurprising , but the performances by phifer and black are ultimately winning . you'll find yourself wishing that you and they were in another movie . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it plods along methodically , somehow under the assumption that its " dead wife communicating from beyond the grave " framework is even remotely new or interesting . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'they do a good job of painting this family dynamic for the audience but they tried to squeeze too many elements into the film . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'not every animated film from disney will become a classic , but forgive me if i\'ve come to expect more from this studio than some 79-minute after-school " cartoon " . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the piano teacher is not an easy film . it forces you to watch people doing unpleasant things to each other and themselves , and it maintains a cool distance from its material that is deliberately unsettling . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b' . . . understands that a generation defines its music as much as the music defines a generation . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a sluggish pace and lack of genuine narrative hem the movie in every bit as much as life hems in the spirits of these young women . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it isn't that stealing harvard is a horrible movie\xc2\x97if only it were that grand a failure ! it's just that it's so not-at-all-good . and i expect much more from a talent as outstanding as director bruce mcculloch . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'barry sonnenfeld owes frank the pug big time', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# ...
# tf.Tensor(b'a model of what films like this should be like . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b' . . . a trashy little bit of fluff stuffed with enjoyable performances and a bewildering sense of self importance', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"although god is great addresses interesting matters of identity and heritage , it's hard to shake the feeling that it was intended to be a different kind of film . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b' ( rises ) above its oh so hollywood rejiggering and its conventional direction to give the film a soul and an unabashed sense of good old fashioned escapism . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the film makes a fatal mistake : it asks us to care about a young man whose only apparent virtue is that he is not quite as unpleasant as some of the people in his life . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"however stale the material , lawrence's delivery remains perfect ; his great gift is that he can actually trick you into thinking some of this worn-out , pandering palaver is actually funny . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'quite simply , a joy to watch and  especially  to listen to . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'simultaneously heartbreakingly beautiful and exquisitely sad . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'an unflinching , complex portrait of a modern israel that is rarely seen on screen . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b' " take care of my cat "  is an honestly nice little film that takes us on an examination of young adult life in urban south korea through the hearts and minds of the five principals . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b" . . . the same tired old gags , modernized for the extreme sports generation . there's already been too many of these films . . . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's a visual delight and a decent popcorn adventure , as long as you don't try to look too deep into the story", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'neither a rousing success nor a blinding embarrassment . still , it just sits there like a side dish no one ordered . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"a movie in which laughter and self-exploitation merge into jolly soft-porn 'empowerment . '", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'pumpkin takes an admirable look at the hypocrisy of political correctness , but it does so with such an uneven tone that you never know when humor ends and tragedy begins . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'predictable and cloying , though brown sugar is so earnest in its yearning for the days before rap went nihilistic that it summons more spirit and bite than your average formulaic romantic quadrangle . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'aggravating and tedious . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'an encouraging effort from mccrudden', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"bogdanovich tantalizes by offering a peep show into the lives of the era's creme de la celluloid . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the best animated feature to hit theaters since beauty and the beast 11 years ago . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'did the film inform and educate me ? yes . did it move me to care about what happened in 1915 armenia ? no . and that is where ararat went astray . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"kidman is really the only thing that's worth watching in birthday girl , a film by the stage-trained jez butterworth ( mojo ) that serves as yet another example of the sad decline of british comedies in the post-full monty world . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"if you're hard up for raunchy college humor , this is your ticket right here . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"chris columbus' sequel is faster , livelier and a good deal funnier than his original . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"it's deep-sixed by a compulsion to catalog every bodily fluids gag in there's something about mary and devise a parallel clone-gag . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"by the final whistle you're convinced that this mean machine was a decent tv outing that just doesn't have big screen magic . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'george lucas returns as a visionary with a tale full of nuance and character dimension . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the movie has generic virtues , and despite a lot of involved talent , seems done by the numbers . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'too infuriatingly quirky and taken with its own style . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'a big , gorgeous , sprawling swashbuckler that delivers its diversions in grand , uncomplicated fashion . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'lavishly , exhilaratingly tasteless . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b" . . . by the time it's done with us , mira nair's new movie has its audience giddy with the delight of discovery , of having been immersed in a foreign culture only to find that human nature is pretty much the same all over . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"about schmidt is nicholson's goofy , heartfelt , mesmerizing king lear . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the urban landscapes are detailed down to the signs on the kiosks , and the color palette , with lots of somber blues and pinks , is dreamy and evocative . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'abandons all pretense of creating historical context and waltzes off into a hectic soap about the ups and downs of the heavy breathing between the two artists . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'from a deceptively simple premise , this deeply moving french drama develops a startling story that works both as a detailed personal portrait and as a rather frightening examination of modern times . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'narc is all menace and atmosphere . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'part of the charm of satin rouge is that it avoids the obvious with humour and lightness . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the film's bathos often overwhelms what could have been a more multifaceted look at this interesting time and place . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"there's a whole heap of nothing at the core of this slight coming-of-age/coming-out tale . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'twohy knows how to inflate the mundane into the scarifying , and gets full mileage out of the rolling of a stray barrel or the unexpected blast of a phonograph record . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'not a bad premise , but the execution is lackluster at best . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'may not be a breakthrough in filmmaking , but it is unwavering and arresting . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the film is like a series of beginnings and middles that never take off . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it is risky , intelligent , romantic and rapturous from start to finish . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"ihops don't pile on this much syrup . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"on the surface a silly comedy , scotland , pa would be forgettable if it weren't such a clever adaptation of the bard's tragic play . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"aptly named , this shimmering , beautifully costumed and filmed production doesn't work for me . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the film has the thrown-together feel of a summer-camp talent show : hastily written , underrehearsed , arbitrarily plotted and filled with crude humor and vulgar innuendo . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'feels at times like a giant commercial for universal studios , where much of the action takes place . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'aan opportunity wasted . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's like a drive-by . you can drive right by it without noticing anything special , save for a few comic turns , intended and otherwise . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's a frightful vanity film that , no doubt , pays off what debt miramax felt they owed to benigni . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"movies like this are selling the old european candor , the old wink of 'bold' revelation . but in 2002 , such revelations wilt . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'this extremely unfunny film clocks in at 80 minutes , but feels twice as long . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'shrewd but pointless . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"if you can tolerate the redneck versus blueblood cliches that the film trades in , sweet home alabama is diverting in the manner of jeff foxworthy's stand up act . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"can't kick about the assembled talent and the russos show genuine promise as comic filmmakers . still , this thing feels flimsy and ephemeral . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"like mike isn't interested in recycling old cliches . it wants to tweak them with a taste of tangy new humor . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'we have an actor who is great fun to watch performing in a film that is only mildly diverting . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"a sly game of cat and mouse that's intense and thrilling at times , but occasionally stretches believability to its limits and relies on predictable plot contrivances . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"by the end of the movie , you're definitely convinced that these women are spectacular . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the thing about guys like evans is this : you're never quite sure where self promotion ends and the truth begins . but as you watch the movie , you're too interested to care . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"the film's images give a backbone to the company and provide an emotional edge to its ultimate demise . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a dim-witted and lazy spin-off of the animal planet documentary series , crocodile hunter is entertainment opportunism at its most glaring . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"it's tough being a black man in america , especially when the man has taken away your car , your work-hours and denied you health insurance . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the movie slides downhill as soon as macho action conventions assert themselves . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'it jumps around with little logic or continuity , presenting backstage bytes of information that never amount to a satisfying complete picture of this particular , anciently demanding m\xc3\xa9tier . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"they presume their audience won't sit still for a sociology lesson , however entertainingly presented , so they trot out the conventional science-fiction elements of bug-eyed monsters and futuristic women in skimpy clothes . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b"the script feels as if it started to explore the obvious voyeuristic potential of 'hypertime' but then backed off when the producers saw the grosses for spy kids . ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the obnoxious special effects , the obligatory outbursts of flatulence and the incessant , so-five-minutes-ago pop music on the soundtrack overwhelm what is left of the scruffy , dopey old hanna-barbera charm . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'with a confrontational stance , todd solondz takes aim on political correctness and suburban families . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'a solidly entertaining little film . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"a highly intriguing thriller , coupled with some ingenious plot devices and some lavishly built settings . . it's a worthwhile tutorial in quantum physics and slash dash", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'as if to prove a female director can make a movie with no soft edges , kathryn bigelow offers no sugar coating or interludes of lightness . her film is unrelentingly claustrophobic and unpleasant . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"suffice to say that after seeing this movie in imax form , you'll be more acquainted with the tiniest details of tom hanks' face than his wife is . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'many a parent and their teen ( or preteen ) kid could bond while watching a walk to remember . so could young romantics out on a date . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b'the only thing " swept away " is the one hour and thirty-three minutes spent watching this waste of time . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'just offbeat enough to keep you interested without coming close to bowling you over . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b"what's next ? the porky's revenge : ultimate edition ? ", shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'the script becomes lifeless and falls apart like a cheap lawn chair . ', shape=(), dtype=string) tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(b'bound to appeal to women looking for a howlingly trashy time . ', shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(b" . . . one of the more influential works of the 'korean new wave' . ", shape=(), dtype=string) tf.Tensor(0, shape=(), dtype=int32)

# %%
unique_positive_words = set([line for line in positive for word in line.split()])
unique_negative_words = set([line for line in negative for word in line.split()])
total = VOCAB_SIZE =  len(list(unique_positive_words.union(unique_negative_words)))

# %%
import re

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )

# %%
vectorize_layer = tf.keras.layers.TextVectorization(
    standardize=custom_standardization,
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=max_length(positive, negative),
)

# %%
text_data = dataset.map(lambda x, y: x)

# %%
vectorize_layer.adapt(text_data)

# %%
def vectorize_text(text, label):
    text = tf.expand_dims(text, -1)
    return vectorize_layer(text), tf.expand_dims(label, -1)

train = dataset.map(vectorize_text).cache().prefetch(buffer_size=10)

# %% [markdown]
# ## Building the Model

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
x = tf.keras.layers.Embedding(total, 128)(inputs)
x = tf.keras.layers.Dropout(0.5)(x)


lstm_x = tf.keras.layers.LSTM(64, return_sequences=True)
x = tf.keras.layers.Bidirectional(lstm_x)(x)

x = tf.keras.layers.Conv1D(128, 5, padding='valid', activation="relu", strides=3)(x)
x = tf.keras.layers.Conv1D(128, 5, padding='valid', activation='relu', strides=3)(x)
x = tf.keras.layers.GlobalMaxPooling1D()(x)

x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
model = tf.keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
epochs = 2
model.fit(train, epochs=epochs)
# Out:
# Epoch 1/2
#     348/Unknown 105s 286ms/step - accuracy: 0.5059 - loss: 0.7032
